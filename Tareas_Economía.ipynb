# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasFru/Terminal-de-Economia./blob/main/Tareas_Econom%C3%ADa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicios de clase 1.

# %% [markdown]
# ##Declaración de variables.

# %%
cadena = "Hola mundo"
entero = 5
flotante = 3.1416

# %%
type(cadena)
# Out:
# str

# %%
type(entero)
# Out:
# int

# %%
type(flotante)
# Out:
# float

# %% [markdown]
# ##2. Operaciones.

# %%
x = 12
y = 3

# %%
x + y
# Out:
# 15

# %%
x-y
# Out:
# 9

# %%
x*y
# Out:
# 36

# %%
x/y
# Out:
# 4.0

# %%
x ** y
# Out:
# 1728

# %%
x % y
# Out:
# 0

# %%
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x**y)
print(x % y)
x // y
# Out:
# 15
# 9
# 36
# 4.0
# 1728
# 0
# 4

# %% [markdown]
# ##3. Concatenacion de cadenas.

# %%
n=input("Escribe tu nombre:")
# Out:
# Escribe tu nombre:Sebastian

# %%
edad2 = input("Escribe tu edad:")
# Out:
# Escribe tu edad:21

# %%
print("Hola", n, "tienes", edad2 )
# Out:
# Hola Sebastian tienes 21

# %% [markdown]
# ##4. Conversion de tipo.

# %%
variable = "456.78"

# %%
variable_f = float(variable)

# %%
int(variable_f)
# Out:
# 456

# %%
##5. Operaciones con datos del usuario.

# %%
n1=input("Escribe un número:")
# Out:
# Escribe un número:12

# %%
n2=input("Escribe otro número: ")
# Out:
# Escribe otro número: 42

# %%
f1=float(n1)
f2=float(n2)

# %%
suma=f1+f2

# %%
resta=f1-f2

# %%
mult=f1*f2

# %%
div=f1/f2

# %%
print(f"{f1} + {f2} = {suma}")
print(f"{f1} - {f2} = {resta}")
print(f"{f1} * {f2} = {mult}")
print(f"{f1} / {f2} = {div}")
# Out:
# 12.0 + 42.0 = 54.0
# 12.0 - 42.0 = -30.0
# 12.0 * 42.0 = 504.0
# 12.0 / 42.0 = 0.2857142857142857

# %% [markdown]
# #Ejercicios de clase 2.

# %% [markdown]
# ## Ejercicio 1.

# %%
num = input("Ingresa un número entero:")
n=int(num)
if n>0:
  print("EL numero es positivo")
elif n<0:
  print("El numero es negativo")
else:
  print("El numero es cero")
# Out:
# Ingresa un número entero:23
# EL numero es positivo

# %% [markdown]
# ## Ejercicio 2.

# %%
for i in range(1,51):
  if i%3 == 0:
    print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48

# %% [markdown]
# ## Ejercicio 3.

# %%
n=0
suma=0
while n >= 0:
  num=input("Escribe un numero entero positivo")
  n=int(num)
  if n >= 0:
    suma=suma+n
print(suma)
# Out:
# Escribe un numero entero positivo12
# Escribe un numero entero positivo12
# Escribe un numero entero positivo3
# Escribe un numero entero positivo-2
# 27

# %% [markdown]
# ## Ejercicio 4.

# %%
flag=0
lista = ['1','20','5','3']
for num in lista:
  if int(num) > 100:
    flag=1
    break
if flag == 1:
  print("Numero demasiado grande")
else:
  print("Todos los numero estan dentro del rango permitido")
# Out:
# Todos los numero estan dentro del rango permitido

# %% [markdown]
# ## Ejercicio 5.

# %%
for i in range(1,20):
  if i % 4 == 0:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 13
# 14
# 15
# 17
# 18
# 19

# %% [markdown]
# ## Ejercicio 6.

# %%
import random

rn = random.randint(1,10)  # Generates a random integer between 1 and 100 (inclusive)
m=int(num)
ganador=0
while ganador == 0:
  num= input("Adivina el numero del 1 al 10: ")
  if m == rn:
    print("Ganaste")
    ganador=13
  if ganador == 0:
    num= input("Adivina el numero del 1 al 10: ")
    break
  elif m < 0 and m > 10:
    print()
# Out:
# Adivina el numero del 1 al 103
# Adivina el numero del 1 al 102

# %% [markdown]
# #Ejercicios de clase 3

# %% [markdown]
# ##Ejercicio 1.

# %%
ciudades = ['Queretaro', 'Monterrey','Guadalajara', 'Puebla', 'Tijuana']
ciudades.extend(['Cancun', 'Ciudad de México'])
ciudades
# Out:
# ['Queretaro',
#  'Monterrey',
#  'Guadalajara',
#  'Puebla',
#  'Tijuana',
#  'Cancun',
#  'Ciudad de México']

# %%
ciudades.sort()
ciudades
# Out:
# ['Cancun',
#  'Ciudad de México',
#  'Guadalajara',
#  'Monterrey',
#  'Puebla',
#  'Queretaro',
#  'Tijuana']

# %%
ciudades.remove('Puebla')
print(ciudades)
# Out:
# ['Cancun', 'Ciudad de México', 'Guadalajara', 'Monterrey', 'Queretaro', 'Tijuana']

# %% [markdown]
# ##Ejercicio 2

# %%
numeros = (3, 8, 15, 22, 7)
num = list(numeros)
num.append(10)
num.sort()
num.reverse()
numeros_2 = tuple(num)
print(numeros_2)
# Out:
# (22, 15, 10, 8, 7, 3)

# %% [markdown]
# ##Ejercicio 3.

# %%
A = {"manzana", "pera", "uvas", "sandia"}
B = {"pera", "mango", "piña", "sandia"}

# %%
union = A|B
print(union)
# Out:
# {'mango', 'sandia', 'piña', 'manzana', 'pera', 'uvas'}

# %%
intersec = A&B
print(intersec)
# Out:
# {'pera', 'sandia'}

# %%
diff = A - B
print(diff)
# Out:
# {'uvas', 'manzana'}

# %%
if 'uvas' in diff:
  print('Si')
else:
  print('No')
# Out:
# Si

# %% [markdown]
# ##Ejercicio 4.

# %%
inventario = {"laptops": 10,
              "teclados": 25,
              "mouse": 50}
inventario.update({"monitores":15})
print(inventario)
# Out:
# {'laptops': 10, 'teclados': 25, 'mouse': 50, 'monitores': 15}

# %%
inventario["laptops"]=8

# %%
del inventario["mouse"]
print(inventario)
# Out:
# {'laptops': 8, 'teclados': 25, 'monitores': 15}

# %% [markdown]
# ##Ejercicio 5.

# %%
cadena = "Python es un lenguaje de programación poderoso y versátil"

# %%
c = cadena.upper()
print(c)
# Out:
# PYTHON ES UN LENGUAJE DE PROGRAMACIÓN PODEROSO Y VERSÁTIL

# %%
c2 = c.replace('PODEROSO', 'POPULAR')
print(c2)
# Out:
# PYTHON ES UN LENGUAJE DE PROGRAMACIÓN POPULAR Y VERSÁTIL

# %%
lista=c2.split()

# %%
e = 0
for i in lista:
  e=e+i.count("E")
print(e)
# Out:
# 5

# %% [markdown]
# ## Ejercicio 6

# %%
palabras = ["python", "código", "datos", "python", "analisis", "datos", "código"]
numpalabras = {}
for i in palabras:
  num = 0
  for n in palabras:
    if i == n:
      num = num + 1
  numpalabras[i] = num
print(numpalabras)
# Out:
# {'python': 2, 'código': 2, 'datos': 2, 'analisis': 1}

# %% [markdown]
# ## Ejercicio 7

# %%
personajes = {"guerrrero":{"fuerza": 80, "salud":100},
              "arquero":{"fuerza": 65, "salud":80},
              "mago":{"fuerza": 50, "salud":60}}
personajes["hechicero"]={"fuerza": 70, "salud":85}
n=personajes["arquero"]["fuerza"]
personajes["arquero"]["fuerza"]=n+10
saludmax = 0
for i in personajes:
  n=personajes[i]["salud"]
  if n > saludmax:
    saludmax = n
    print("El personaje con más salud es: ",i)
# Out:
# El personaje con más salud es:  guerrrero

# %% [markdown]
# ## Ejercicio 8

# %%
cuentas = {
    "1234":{"titular":"Juan", "saldo":5000},
    "5678":{"titular":"Ana", "saldo":7000},
    "9101":{"titular":"Luis", "saldo":3000}
}
cuentas["1234"]["saldo"]=cuentas["1234"]["saldo"]+1000
cuentas["5678"]["saldo"]=cuentas["5678"]["saldo"]-2000
print(cuentas)
# Out:
# {'1234': {'titular': 'Juan', 'saldo': 6000}, '5678': {'titular': 'Ana', 'saldo': 5000}, '9101': {'titular': 'Luis', 'saldo': 3000}}

# %%
n=0
for i in cuentas:
  n=n+cuentas[i]["saldo"]
print("El saldo total del banco es: ",n)
# Out:
# El saldo total del banco es:  14000

# %% [markdown]
# ## Ejercicio 9

# %%
c = "El analisis de datos es esencial en el mundo actual"

# %%
palabras=c.split()

# %%
mayor = 0
menor =100
for i in palabras:
  n=len(i)
  if mayor <= n:
    mayor = len(i)
  elif menor >= n:
    menor = len(i)
print(mayor)
print(menor)
# Out:
# 8
# 2

# %%
print("Las palabras más cortas son: ")
for i in palabras:
  if len(i) == menor:
    print(i)
# Out:
# Las palabras más cortas son:
# El
# de
# es
# en
# el

# %%
print("Las palabras mas largas son: ")
for i in palabras:
  if len(i) == mayor:
    print(i)
# Out:
# Las palabras mas largas son:
# analisis
# esencial

# %%
palabrascona = 0
for i in palabras:
  if i.find('a') != -1:
    palabrascona = palabrascona + 1
print("El número de palabras que contienen la letra 'a' es: ",palabrascona)
# Out:
# El número de palabras que contienen la letra 'a' es:  4

# %%
palabras.sort()
print(palabras)
# Out:
# ['El', 'actual', 'analisis', 'datos', 'de', 'el', 'en', 'es', 'esencial', 'mundo']

# %%
min = c.lower()
min2 = min.split()
min2.sort()
print(min2)
# Out:
# ['actual', 'analisis', 'datos', 'de', 'el', 'el', 'en', 'es', 'esencial', 'mundo']

# %% [markdown]
# ## Ejercicio 10

# %%
inventario = {"manzana":50,
               "naranjas":35,
               "platanos":20}

# %%
agotados = {'pera', 'piña','mandarina','sandia'}

# %%
suma = 0
mayor = 0
for i in inventario:
  if mayor < inventario[i]:
    mayor = inventario[i]
    m=i
  suma = suma + inventario[i]
print("El total de producto disponible es:",suma)
print("El producto con mayor cantidad disponible es:",m)
# Out:
# El total de producto disponible es: 105
# El producto con mayor cantidad disponible es: manzana

# %% [markdown]
# #Ejercicios 4.

# %% [markdown]
# ##Calculadora.

# %%
def calculadora(a, b, operacion):
  try:
    if operacion == '+':
      op = a + b
    elif operacion == '-':
      op = a - b
    elif operacion == '*':
      op = a * b
    elif operacion == '/':
      # Added a check for division by zero
      if b == 0:
        print('Error: Division por cero')
        return None # Return None or handle the error as appropriate
      op = a / b
    elif operacion == '%':
      op = a % b
    elif operacion == '**':
      op = a ** b
    else:
      print('Operacion no valida')
      return None  # Return None when the operation is invalid
    return op
  except ValueError:
    # This except block will not be reached by the current code but is kept
    # in case the inputs 'a' or 'b' were user input and not yet converted.
    print('El valor ingresado no es un numero')
    return None # Return None in case of a ValueError
  except ZeroDivisionError:
    # This except block is now redundant due to the explicit check for b == 0,
    # but it can be kept as a safeguard or removed.
    print('El valor ingresado no es un numero')
    return None # Return None in case of a ZeroDivisionError

# %%
calculadora(2,5,'?')
# Out:
# Operacion no valida

# %% [markdown]
# ##Conversor de temperatura.

# %%
def convertir_temperatura(valor, unidad_origen, unidad_destino):
    try:
        valor = float(valor)
        unidad_origen = unidad_origen.upper()
        unidad_destino = unidad_destino.upper()

        if unidad_origen not in ['C', 'F', 'K'] or unidad_destino not in ['C', 'F', 'K']:
            raise ValueError("Unidad inválida. Usa 'C', 'F' o 'K'.")

        if unidad_origen == 'K' and valor < 0:
            raise ValueError("La temperatura en Kelvin no puede ser negativa.")
        if unidad_origen == 'C' and valor < -273.15:
            raise ValueError("La temperatura en Celsius no puede ser menor que -273.15.")
        if unidad_origen == 'F' and valor < -459.67:
            raise ValueError("La temperatura en Fahrenheit no puede ser menor que -459.67.")

        # Conversión a Celsius
        if unidad_origen == 'F':
            celsius = (valor - 32) * 5/9
        elif unidad_origen == 'K':
            celsius = valor - 273.15
        else:
            celsius = valor

        # Conversión desde Celsius
        if unidad_destino == 'F':
            return celsius * 9/5 + 32
        elif unidad_destino == 'K':
            return celsius + 273.15
        else:
            return celsius
    except ValueError as e:
        return f"Error: {e}"
    except Exception:
        return "Error inesperado."

# %% [markdown]
# ##Generador contrasenas.

# %%
import random
import string

def generar_contraseña(longitud):
    try:
        longitud = int(longitud)
        if longitud < 6:
            raise ValueError("La longitud mínima es 6.")

        caracteres = string.ascii_letters + string.digits + string.punctuation
        contraseña = ''.join(random.choice(caracteres) for _ in range(longitud))
        return contraseña
    except ValueError as e:
        return f"Error: {e}"
    except Exception:
        return "Error inesperado al generar la contraseña."

# %% [markdown]
# ##Estadisticas.

# %%
import statistics

def estadisticas(lista):
    try:
        if not lista:
            raise ValueError("La lista está vacía.")
        lista_numerica = [float(x) for x in lista]
        promedio = sum(lista_numerica) / len(lista_numerica)
        mayor = max(lista_numerica)
        menor = min(lista_numerica)
        mediana = statistics.median(lista_numerica)
        return {
            'promedio': promedio,
            'mayor': mayor,
            'menor': menor,
            'mediana': mediana
        }
    except ValueError as e:
        return f"Error: {e}"
    except Exception:
        return "Error: Asegúrate de que todos los elementos sean numéricos."

# %% [markdown]
# ##Usuario y contra.

# %%
import re

def validar_usuario_contraseña(usuario, contraseña):
    try:
        if not usuario or not contraseña:
            raise ValueError("Usuario o contraseña vacíos.")

        if len(usuario) < 5:
            raise ValueError("El usuario debe tener al menos 5 caracteres.")

        if len(contraseña) < 8:
            raise ValueError("La contraseña debe tener al menos 8 caracteres.")
        if not re.search(r"[A-Z]", contraseña):
            raise ValueError("La contraseña debe incluir al menos una mayúscula.")
        if not re.search(r"[0-9]", contraseña):
            raise ValueError("La contraseña debe incluir al menos un número.")

        return "Usuario y contraseña válidos."
    except ValueError as e:
        return f"Error: {e}"
    except Exception:
        return

# %% [markdown]
# #Eejercicios Numpy.

# %% [markdown]
# ## Ejercicio 1.

# %%
P = input("Introduce el Capital principal: ")
r = input("Introduce la tasa de interés: ")
t = input("Introduce el tiempo en años: ")
n = input("Introduce el número de veces que se capitaliza: ")
# Out:
# Introduce el Capital principal: 2000
# Introduce la tasa de interés: .2
# Introduce el tiempo en años: 4
# Introduce el número de veces que se capitaliza: 12

# %%
P1=float(P)
r1=float(r)
t1=float(t)
n1=float(n)

# %%
A = (1+ r1/n1)**(n1*t1) + P1

# %%
print("El capital acumulado es A = ",A)
# Out:
# El capital acumulado es A =  2002.2109150810625

# %% [markdown]
# ##Ejercicio 2.

# %%
import math

def area_y_volumen_esfera():
    try:
        r = float(input("Introduce el radio de la esfera: "))
        if r < 0:
            raise ValueError("El radio no puede ser negativo.")
        area = 4 * math.pi * math.pow(r, 2)
        volumen = (4 / 3) * math.pi * math.pow(r, 3)
        print(f"Área: {area:.3f}")
        print(f"Volumen: {volumen:.3f}")
    except ValueError as e:
        print("Error:", e)

area_y_volumen_esfera()
# Out:
# Introduce el radio de la esfera: 3
# Área: 113.097
# Volumen: 113.097

# %% [markdown]
# ##Ejercicio 3.

# %%
import random

def simular_precios():
    precio = 100
    precios = [precio]
    for _ in range(10):
        variacion = random.uniform(-0.05, 0.05)
        precio *= (1 + variacion)
        precios.append(round(precio, 2))
    print("Precios simulados:", precios)

simular_precios()
# Out:
# Precios simulados: [100, 95.37, 97.73, 97.77, 102.43, 100.92, 99.2, 95.06, 93.06, 97.36, 100.92]

# %% [markdown]
# ##Ejercicio 4.

# %%
import random
from collections import Counter

def lanzar_dado():
    resultados = [random.randint(1, 6) for _ in range(10)]
    conteo = Counter(resultados)
    print("Resultados:", resultados)
    for i in range(1, 7):
        print(f"{i} salió {conteo[i]} veces")

lanzar_dado()
# Out:
# Resultados: [6, 2, 5, 5, 6, 1, 3, 2, 3, 6]
# 1 salió 1 veces
# 2 salió 2 veces
# 3 salió 2 veces
# 4 salió 0 veces
# 5 salió 2 veces
# 6 salió 3 veces

# %% [markdown]
# ##Ejercicio 5.

# %%
import random
import string

def generar_contraseña_segura(longitud=12):
    caracteres = string.ascii_letters + string.digits + string.punctuation
    contraseña = ''.join(random.choice(caracteres) for _ in range(longitud))
    print("Contraseña generada:", contraseña)

generar_contraseña_segura()
# Out:
# Contraseña generada: /3Dhcc|{`VT)

# %% [markdown]
# ##Ejercicio 6.

# %%
from datetime import datetime, timedelta

def calcular_vencimiento():
    try:
        fecha_str = input("Ingresa la fecha de inicio (YYYY-MM-DD): ")
        dias = int(input("Duración del plazo (días): "))
        fecha_inicio = datetime.strptime(fecha_str, "%Y-%m-%d")
        vencimiento = fecha_inicio + timedelta(days=dias)
        print("Fecha de vencimiento:", vencimiento.strftime("%d de %B de %Y"))
    except Exception as e:
        print("Error:", e)

calcular_vencimiento()
# Out:
# Ingresa la fecha de inicio (YYYY-MM-DD): 2003-12-01
# Duración del plazo (días): 12
# Fecha de vencimiento: 13 de December de 2003

# %% [markdown]
# ##Ejercicio 7.

# %%
from datetime import datetime

def diferencia_de_fechas():
    try:
        fecha1 = input("Ingresa la primera fecha (YYYY-MM-DD): ")
        fecha2 = input("Ingresa la segunda fecha (YYYY-MM-DD): ")
        f1 = datetime.strptime(fecha1, "%Y-%m-%d")
        f2 = datetime.strptime(fecha2, "%Y-%m-%d")
        dias = abs((f2 - f1).days)
        print(f"Han pasado {dias} días entre ambas fechas.")
    except Exception as e:
        print("Error:", e)

diferencia_de_fechas()
# Out:
# Ingresa la primera fecha (YYYY-MM-DD): 2003-12-04
# Ingresa la segunda fecha (YYYY-MM-DD): 2004-12-05
# Han pasado 367 días entre ambas fechas.

# %% [markdown]
# ##Ejercicio 8.

# %%
import random

def sorteo_participantes():
    nombres = input("Ingresa al menos 5 nombres separados por comas: ").split(",")
    nombres = [nombre.strip() for nombre in nombres if nombre.strip()]
    if len(nombres) < 5:
        print("Debe haber al menos 5 participantes.")
        return
    ganador = random.choice(nombres)
    print("El ganador es:", ganador)

sorteo_participantes()
# Out:
# Ingresa al menos 5 nombres separados por comas: Juan, Sebas, luis, pedro, pedro2
# El ganador es: pedro

# %% [markdown]
# ##Ejercicio 9.

# %%
import math

def ahorro_mensual():
    try:
        aporte = float(input("Aporte mensual: "))
        meses = int(input("Número de meses: "))
        tasa_mensual = 0.01  # 1% mensual
        total = 0
        for i in range(1, meses + 1):
            total += aporte * math.pow(1 + tasa_mensual, meses - i)
        print(f"Monto total ahorrado: ${total:.2f}")
    except Exception as e:
        print("Error:", e)

ahorro_mensual()
# Out:
# Aporte mensual: 1000
# Número de meses: 12
# Monto total ahorrado: $12682.50

# %% [markdown]
# ##Ejercicio 10.

# %%
from datetime import datetime, timedelta

def proxima_fecha_pago():
    try:
        fecha_pago_str = input("Fecha del último pago (YYYY-MM-DD): ")
        fecha_pago = datetime.strptime(fecha_pago_str, "%Y-%m-%d")
        proxima_fecha = fecha_pago + timedelta(days=30)
        print("Próximo pago:", proxima_fecha.strftime("%d de %B de %Y"))
    except Exception as e:
        print("Error:", e)

proxima_fecha_pago()
# Out:
# Fecha del último pago (YYYY-MM-DD): 2003-04-05
# Próximo pago: 05 de May de 2003

# %%
# prompt: Subir un exel

from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-29206e19-7d45-43a9-9720-cf407c1130e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29206e19-7d45-43a9-9720-cf407c1130e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Asignment_1.xlsx')

# %% [markdown]
# ##Pregunta 0.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import datetime as dt
import random

# Cargar archivo desde Google Colab
from google.colab import files
uploaded = files.upload()

# Leer archivo
df = pd.read_excel('Asignment_1.xlsx', sheet_name='in')
df['time_est'] = pd.to_datetime(df['time_est'])  # Convertimos fecha
df.head()
# Out:
#      <input type="file" id="files-d7bf3741-34ad-4369-b9c0-fae292940efe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7bf3741-34ad-4369-b9c0-fae292940efe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Pregunta 1.

# %%
# Casos únicos
print("Casos únicos:", df['asset_id'].nunique())

# Zonas únicas
print("\nZonas únicas:")
print(df['Zone'].unique())

# POIs por zona
print("\nPOIs por zona:")
print(df.groupby('Zone')['device_id'].nunique())
# Out:
# Casos únicos: 18
#
# Zonas únicas:
# ['dock_doors_DC1' 'dock_doors_DC2' 'Forklift3_DC1' 'pallet_assembly_DC1'
#  'PhoneKit1Bridge' 'PhoneKit2Bridge' 'PhoneKit2GW' 'point_of_sale_Store'
#  'receiving_Store' 'staging_DC1' 'staging_DC2' 'store_back_Store'
#  'store_front_Store' 'Forklift1_DC1' 'PhoneKit1GW']
#
# POIs por zona:
# Zone
# Forklift1_DC1          1
# Forklift3_DC1          1
# PhoneKit1Bridge        1
# PhoneKit1GW            1
# PhoneKit2Bridge        1
# PhoneKit2GW            1
# dock_doors_DC1         4
# dock_doors_DC2         3
# pallet_assembly_DC1    2
# point_of_sale_Store    2
# receiving_Store        3
# staging_DC1            5
# staging_DC2            4
# store_back_Store       3
# store_front_Store      6
# Name: device_id, dtype: int64

# %% [markdown]
# ##Pregunta 2.

# %%
# Rango de temperatura
temp_min = df['Temperature_C'].min()
temp_max = df['Temperature_C'].max()
print(f"Temperatura mínima: {temp_min} °C")
print(f"Temperatura máxima: {temp_max} °C")

# Dónde se observaron
print("\nLugar de temperatura más baja:")
print(df[df['Temperature_C'] == temp_min][['Zone', 'Site', 'time_est']])

print("\nLugar de temperatura más alta:")
print(df[df['Temperature_C'] == temp_max][['Zone', 'Site', 'time_est']])
# Out:
# Temperatura mínima: 19.0 °C
# Temperatura máxima: 44.0 °C
#
# Lugar de temperatura más baja:
#                    Zone   Site                time_est
# 92279  store_back_Store  Store 2022-08-04 21:17:51.079
#
# Lugar de temperatura más alta:
#                    Zone   Site                time_est
# 57195   receiving_Store  Store 2022-08-04 09:53:28.320
# 57196   receiving_Store  Store 2022-08-04 09:54:25.207
# 57197   receiving_Store  Store 2022-08-04 09:54:53.887
# 57199   receiving_Store  Store 2022-08-04 09:57:24.778
# 59985  store_back_Store  Store 2022-08-04 09:55:54.070

# %% [markdown]
# ##Pregunta 3.

# %%
# Seleccionamos un asset_id específico
asset = df['asset_id'].unique()[0]
df_case = df[df['asset_id'] == asset]

# Gráfico de zona a lo largo del tiempo
plt.figure(figsize=(12, 4))
sns.lineplot(data=df_case, x='time_est', y='Zone', marker='o')
plt.title(f'Ubicación del asset_id: {asset} a lo largo del tiempo')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pregunta 4.

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(data=df_case, x='time_est', y='Temperature_C', marker='o')
plt.title(f'Temperatura del asset_id: {asset} durante su trayecto')
plt.xlabel("Tiempo")
plt.ylabel("Temperatura (°C)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Pregunta 5.

# %%
fig = px.line_geo(
    df_case,
    lat='lat',
    lon='lng',
    hover_name='Zone',
    title=f'Trayectoria geográfica del asset_id: {asset}'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Pregunta 6.

# %%
# Solo zonas que no son STORE
df_dc = df[df['Zone'] != 'STORE']

# Medimos duración promedio por zona
duration_per_zone = df_dc.groupby('Zone').agg({
    'time_est': ['min', 'max']
})
duration_per_zone['duration'] = duration_per_zone[('time_est', 'max')] - duration_per_zone[('time_est', 'min')]

print("Duración por zona (sin incluir STORE):")
print(duration_per_zone[['duration']].sort_values(by='duration', ascending=True))
# Out:
# Duración por zona (sin incluir STORE):
#                                   duration
#
# Zone
# Forklift3_DC1       0 days 02:32:32.472000
# Forklift1_DC1       0 days 03:28:57.918000
# pallet_assembly_DC1 0 days 03:35:42.153000
# dock_doors_DC1      0 days 03:37:19.474000
# staging_DC1         0 days 03:40:40.664000
# PhoneKit1GW         0 days 16:22:31.375000
# point_of_sale_Store 0 days 22:12:27.378000
# dock_doors_DC2      1 days 04:16:04.876000
# staging_DC2         1 days 04:16:25.440000
# store_front_Store   1 days 04:46:02.454000
# store_back_Store    1 days 04:53:04.404000
# receiving_Store     1 days 04:53:13.775000
# PhoneKit2GW         1 days 18:45:04.858000
# PhoneKit2Bridge     1 days 18:47:19.325000
# PhoneKit1Bridge     1 days 18:52:39.268000

# %% [markdown]
# Las zonas con menor duración de permanencia indican mayor eficiencia. Según los datos, la zona XYZ es la más eficiente mientras que la zona ABC muestra mayor tiempo de permanencia, lo cual puede ser indicador de cuellos de botella logísticos.

# %% [markdown]
# ##Pregunta 7.

# %%
# Filtramos zona STORE
store_data = df[df['Zone'] == 'STORE']

# Calculamos tiempo entre primera y última detección
store_duration = store_data.groupby('asset_id').agg({
    'time_est': ['min', 'max']
})
store_duration['duration'] = store_duration[('time_est', 'max')] - store_duration[('time_est', 'min')]

print("Tiempo promedio en STORE (por asset):")
print(store_duration['duration'].mean())
# Out:
# Tiempo promedio en STORE (por asset):
# NaT

# %% [markdown]
# ##Pregunta 8.

# %% [markdown]
# a. Con el equipo de IT / ingenieros de sensores: Preguntaría por precisión de detección y si hay ruido o repeticiones.
# b. Con supervisores logísticos: Preguntaría por flujos estándar esperados para validar anomalías y zonas ineficientes.

# %% [markdown]
# ##Bonus part.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='Zone', y='Temperature_C')
plt.title("Distribución de temperaturas por zona")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
